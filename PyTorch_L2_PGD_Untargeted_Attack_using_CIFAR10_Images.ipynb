# %% [markdown]
# #### <b>Load Required Libraries</b>

# %%
# load required PyTorch libraries
import torch
import torch.nn as nn
import torch.nn.functional as F

import torchvision
import torchvision.transforms as transforms

# %%
use_cuda = True
device = torch.device("cuda" if use_cuda else "cpu")

# %% [markdown]
# #### <b>Image Visualization</b>

# %%
# load an image visualization library
import matplotlib.pyplot as plt
import PIL

plt.rcParams['figure.figsize'] = [12, 8]
plt.rcParams['figure.dpi'] = 60
plt.rcParams.update({'font.size': 20})

# %%
# show torch.Tensor image
def imshow(tensor):
    image = tensor.cpu().clone()
    image = image.squeeze(0) # [3, H, W]
    image = transforms.ToPILImage()(image)
    # show an image whose values are between [0, 1]
    plt.imshow(image)
    plt.show()

# %% [markdown]
# #### <b>Load Pre-trained Classification Model</b>

# %%
# !wget https://postechackr-my.sharepoint.com/:u:/g/personal/dongbinna_postech_ac_kr/EcpGMF03mR9Ko1MM-kMSmloB4ceabuYCvnHaGZPgLNMzrA?download=1 -O cifar10_model.pth
# Out:
# --2021-03-10 07:49:30--  https://postechackr-my.sharepoint.com/:u:/g/personal/dongbinna_postech_ac_kr/EcpGMF03mR9Ko1MM-kMSmloB4ceabuYCvnHaGZPgLNMzrA?download=1
# Resolving postechackr-my.sharepoint.com (postechackr-my.sharepoint.com)... 13.107.136.9
# Connecting to postechackr-my.sharepoint.com (postechackr-my.sharepoint.com)|13.107.136.9|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: /personal/dongbinna_postech_ac_kr/Documents/Research/Pytorch%20Adversarial%20Training%20on%20CIFAR-10/Pre-trained/basic_training?originalPath=aHR0cHM6Ly9wb3N0ZWNoYWNrci1teS5zaGFyZXBvaW50LmNvbS86dTovZy9wZXJzb25hbC9kb25nYmlubmFfcG9zdGVjaF9hY19rci9FY3BHTUYwM21SOUtvMU1NLWtNU21sb0I0Y2VhYnVZQ3ZuSGFHWlBnTE5NenJBP3J0aW1lPTM5N1hDWm5qMkVn [following]
# --2021-03-10 07:49:30--  https://postechackr-my.sharepoint.com/personal/dongbinna_postech_ac_kr/Documents/Research/Pytorch%20Adversarial%20Training%20on%20CIFAR-10/Pre-trained/basic_training?originalPath=aHR0cHM6Ly9wb3N0ZWNoYWNrci1teS5zaGFyZXBvaW50LmNvbS86dTovZy9wZXJzb25hbC9kb25nYmlubmFfcG9zdGVjaF9hY19rci9FY3BHTUYwM21SOUtvMU1NLWtNU21sb0I0Y2VhYnVZQ3ZuSGFHWlBnTE5NenJBP3J0aW1lPTM5N1hDWm5qMkVn
# Reusing existing connection to postechackr-my.sharepoint.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 44755840 (43M) [application/octet-stream]
# Saving to: ‘cifar10_model.pth’
#
# cifar10_model.pth   100%[===================>]  42.68M  47.5MB/s    in 0.9s
#
# 2021-03-10 07:49:35 (47.5 MB/s) - ‘cifar10_model.pth’ saved [44755840/44755840]

# %%
class BasicBlock(nn.Module):
    expansion = 1

    def __init__(self, in_planes, planes, stride=1):
        super(BasicBlock, self).__init__()
        self.conv1 = nn.Conv2d(in_planes, planes, kernel_size=3, stride=stride, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(planes)
        self.conv2 = nn.Conv2d(planes, planes, kernel_size=3, stride=1, padding=1, bias=False)
        self.bn2 = nn.BatchNorm2d(planes)

        self.shortcut = nn.Sequential()
        if stride != 1 or in_planes != self.expansion*planes:
            self.shortcut = nn.Sequential(
                nn.Conv2d(in_planes, self.expansion*planes, kernel_size=1, stride=stride, bias=False),
                nn.BatchNorm2d(self.expansion*planes)
            )

    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = self.bn2(self.conv2(out))
        out += self.shortcut(x)
        out = F.relu(out)
        return out


class ResNet(nn.Module):
    def __init__(self, block, num_blocks, num_classes=10):
        super(ResNet, self).__init__()
        self.in_planes = 64

        self.conv1 = nn.Conv2d(3, 64, kernel_size=3, stride=1, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(64)
        self.layer1 = self._make_layer(block, 64, num_blocks[0], stride=1)
        self.layer2 = self._make_layer(block, 128, num_blocks[1], stride=2)
        self.layer3 = self._make_layer(block, 256, num_blocks[2], stride=2)
        self.layer4 = self._make_layer(block, 512, num_blocks[3], stride=2)
        self.linear = nn.Linear(512*block.expansion, num_classes)

    def _make_layer(self, block, planes, num_blocks, stride):
        strides = [stride] + [1]*(num_blocks-1)
        layers = []
        for stride in strides:
            layers.append(block(self.in_planes, planes, stride))
            self.in_planes = planes * block.expansion
        return nn.Sequential(*layers)

    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = self.layer1(out)
        out = self.layer2(out)
        out = self.layer3(out)
        out = self.layer4(out)
        out = F.avg_pool2d(out, 4)
        out = out.view(out.size(0), -1)
        out = self.linear(out)
        return out


def ResNet18():
    return ResNet(BasicBlock, [2,2,2,2])

# %%
model = ResNet18()
model = model.to(device)
model = torch.nn.DataParallel(model)
checkpoint = torch.load('./cifar10_model.pth')
model.load_state_dict(checkpoint['net'])
# Out:
# <All keys matched successfully>

# %% [markdown]
# #### <b>Load Test Dataset</b>

# %%
class_names = ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']

transform_test = transforms.Compose([
    transforms.ToTensor(),
])

test_dataset = torchvision.datasets.CIFAR10(root='./data', train=False, download=True, transform=transform_test)
test_dataloader = torch.utils.data.DataLoader(test_dataset, batch_size=64, shuffle=True, num_workers=2)
# Out:
# Files already downloaded and verified

# %%
import numpy as np


def imshow_batch(input, title):
    # torch.Tensor => numpy
    input = input.numpy().transpose((1, 2, 0))
    # display images
    plt.imshow(input)
    plt.title(title)
    plt.show()


# load a batch of validation image
iterator = iter(test_dataloader)

# visualize a batch of validation image
inputs, classes = next(iterator)
out = torchvision.utils.make_grid(inputs[:4])
imshow_batch(out, title='original labels:' + str([class_names[x] for x in classes[:4]]))

print('Original labels >>>>>>>>>>>>>>>>>>>>>>>>>')
for i, label in enumerate(classes[:4]):
    print(f'Image #{i + 1}: {class_names[label]} ({label})')
# Out:
# Original labels >>>>>>>>>>>>>>>>>>>>>>>>>
# Image #1: frog (6)
# Image #2: airplane (0)
# Image #3: deer (4)
# Image #4: horse (7)

# %% [markdown]
# #### <b>Test Phase</b>

# %%
import time

criterion = nn.CrossEntropyLoss()
model.eval()
start_time = time.time()

with torch.no_grad():
    running_loss = 0.
    running_corrects = 0

    for i, (inputs, labels) in enumerate(test_dataloader):
        inputs = inputs.to(device)
        labels = labels.to(device)

        outputs = model(inputs)
        _, preds = torch.max(outputs, 1)
        loss = criterion(outputs, labels)

        running_loss += loss.item()
        running_corrects += torch.sum(preds == labels.data)

        if i == 0:
            print('[Prediction Result Examples]')
            images = torchvision.utils.make_grid(inputs[:4])
            imshow_batch(images.cpu(), title='original labels:' + str([int(x) for x in labels[:4]]) +
                         '\npredicted labels:' + str([int(x) for x in preds[:4]]))
            print('Original labels >>>>>>>>>>>>>>>>>>>>>>>>>')
            for j, label in enumerate(labels[:4]):
                print(f'Image #{i + 1}: {class_names[label]} ({label})')
            print('Predicted labels >>>>>>>>>>>>>>>>>>>>>>>>>')
            for j, label in enumerate(preds[:4]):
                print(f'Image #{i + 1}: {class_names[label]} ({label})')
            images = torchvision.utils.make_grid(inputs[4:8])
            imshow_batch(images.cpu(), title='original labels:' + str([int(x) for x in labels[4:8]]) +
                         '\npredicted labels:' + str([int(x) for x in preds[4:8]]))
            print('Original labels >>>>>>>>>>>>>>>>>>>>>>>>>')
            for j, label in enumerate(labels[4:8]):
                print(f'Image #{i + 1}: {class_names[label]} ({label})')
            print('Predicted labels >>>>>>>>>>>>>>>>>>>>>>>>>')
            for j, label in enumerate(preds[4:8]):
                print(f'Image #{i + 1}: {class_names[label]} ({label})')

    epoch_loss = running_loss / len(test_dataset)
    epoch_acc = running_corrects / len(test_dataset) * 100.
    print('[Validation] Loss: {:.4f} Accuracy: {:.4f}% Time elapsed: {:.4f}s (total {} images)'.format(epoch_loss, epoch_acc, time.time() - start_time, len(test_dataset)))
# Out:
# [Prediction Result Examples]
# Original labels >>>>>>>>>>>>>>>>>>>>>>>>>
# Image #1: horse (7)
# Image #1: ship (8)
# Image #1: automobile (1)
# Image #1: deer (4)
# Predicted labels >>>>>>>>>>>>>>>>>>>>>>>>>
# Image #1: horse (7)
# Image #1: ship (8)
# Image #1: automobile (1)
# Image #1: deer (4)
# Original labels >>>>>>>>>>>>>>>>>>>>>>>>>
# Image #1: truck (9)
# Image #1: deer (4)
# Image #1: dog (5)
# Image #1: bird (2)
# Predicted labels >>>>>>>>>>>>>>>>>>>>>>>>>
# Image #1: truck (9)
# Image #1: deer (4)
# Image #1: dog (5)
# Image #1: bird (2)
# [Validation] Loss: 0.0031 Accuracy: 95.2800% Time elapsed: 6.9047s (total 10000 images)

# %% [markdown]
# #### <b>Prepare Adversarial Attack Libraries</b>

# %%
# !pip install foolbox
# !pip install advertorch
# Out:
# Requirement already satisfied: foolbox in /usr/local/lib/python3.7/dist-packages (3.3.1)
# Requirement already satisfied: GitPython>=3.0.7 in /usr/local/lib/python3.7/dist-packages (from foolbox) (3.1.14)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from foolbox) (54.0.0)
# Requirement already satisfied: requests>=2.24.0 in /usr/local/lib/python3.7/dist-packages (from foolbox) (2.25.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from foolbox) (1.4.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from foolbox) (1.19.5)
# Requirement already satisfied: typing-extensions>=3.7.4.1 in /usr/local/lib/python3.7/dist-packages (from foolbox) (3.7.4.3)
# Requirement already satisfied: eagerpy==0.29.0 in /usr/local/lib/python3.7/dist-packages (from foolbox) (0.29.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.7/dist-packages (from GitPython>=3.0.7->foolbox) (4.0.5)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.24.0->foolbox) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.24.0->foolbox) (2020.12.5)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.24.0->foolbox) (2.10)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.24.0->foolbox) (3.0.4)
# Requirement already satisfied: smmap<4,>=3.0.1 in /usr/local/lib/python3.7/dist-packages (from gitdb<5,>=4.0.1->GitPython>=3.0.7->foolbox) (3.0.5)
# Requirement already satisfied: advertorch in /usr/local/lib/python3.7/dist-packages (0.2.3)

# %%
def get_distance(a, b):
    l0 = torch.norm((a - b).view(a.shape[0], -1), p=0, dim=1)
    l2 = torch.norm((a - b).view(a.shape[0], -1), p=2, dim=1)
    mse = (a - b).view(a.shape[0], -1).pow(2).mean(1)
    linf = torch.norm((a - b).view(a.shape[0], -1), p=float('inf'), dim=1)
    return l0, l2, mse, linf

# %% [markdown]
# #### <b>Adversarial Attack Example 1</b>
#
# * <b>Attack method</b>: 7-step L2 PGD
# * <b>Images</b>: 5,000 valiation images
# * <b>Epsilon size</b>: 0.25

# %%
import time
from advertorch.attacks import L2PGDAttack

criterion = nn.CrossEntropyLoss()
model.eval()
start_time = time.time()

adversary = L2PGDAttack(
    model, loss_fn=nn.CrossEntropyLoss(reduction="sum"),
    eps=0.25, nb_iter=7, eps_iter=0.25/4, clip_min=0.0, clip_max=1.0, targeted=False)

running_loss = 0.
running_corrects = 0
running_length = 0

running_l0 = 0
running_l2 = 0
running_mse = 0
running_linf = 0

for i, (inputs, labels) in enumerate(test_dataloader):
    inputs = inputs.to(device)
    labels = labels.to(device)

    adv_untargeted = adversary.perturb(inputs, labels) # adversarial attack

    outputs = model(adv_untargeted)
    _, preds = torch.max(outputs, 1)
    loss = criterion(outputs, labels)

    running_loss += loss.item()
    running_corrects += torch.sum(preds == labels.data)
    running_length += labels.shape[0]

    l0, l2, mse, linf = get_distance(adv_untargeted, inputs)
    running_l0 += l0.sum().item()
    running_l2 += l2.sum().item()
    running_mse += mse.sum().item()
    running_linf += linf.sum().item()

    if i == 0:
        print('The dimension of an image tensor:', inputs.shape[1:])
        print('[Prediction Result Examples]')
        images = torchvision.utils.make_grid(adv_untargeted[:4])
        imshow_batch(images.cpu(), title='original labels:' + str([int(x) for x in labels[:4]]) +
                      '\npredicted labels:' + str([int(x) for x in preds[:4]]))
        print('Original labels >>>>>>>>>>>>>>>>>>>>>>>>>')
        for j, label in enumerate(labels[:4]):
            print(f'Image #{i + 1}: {class_names[label]} ({label})')
        print('Predicted labels >>>>>>>>>>>>>>>>>>>>>>>>>')
        for j, label in enumerate(preds[:4]):
            print(f'Image #{i + 1}: {class_names[label]} ({label})')
        images = torchvision.utils.make_grid(adv_untargeted[4:8])
        imshow_batch(images.cpu(), title='original labels:' + str([int(x) for x in labels[4:8]]) +
                      '\npredicted labels:' + str([int(x) for x in preds[4:8]]))
        print('Original labels >>>>>>>>>>>>>>>>>>>>>>>>>')
        for j, label in enumerate(labels[4:8]):
            print(f'Image #{i + 1}: {class_names[label]} ({label})')
        print('Predicted labels >>>>>>>>>>>>>>>>>>>>>>>>>')
        for j, label in enumerate(preds[4:8]):
            print(f'Image #{i + 1}: {class_names[label]} ({label})')

    if i % 10 == 0:
        cur_running_loss = running_loss / running_length
        running_acc = running_corrects / running_length * 100.
        print('[Step #{}] Loss: {:.4f} Accuracy: {:.4f}% Time elapsed: {:.4f}s (total {} images)'.format(i, cur_running_loss, running_acc, time.time() - start_time, running_length))

epoch_loss = running_loss / len(test_dataset)
epoch_acc = running_corrects / len(test_dataset) * 100.
print('[Validation] Loss: {:.4f} Accuracy: {:.4f}% Time elapsed: {:.4f}s (total {} images)'.format(epoch_loss, epoch_acc, time.time() - start_time, len(test_dataset)))

print('[Size of Perturbation]')
print('Average L0 distance (the number of changed parameters):', running_l0 / len(test_dataset))
print('Average L2 distance:', running_l2 / len(test_dataset))
print('Average MSE:', running_mse / len(test_dataset))
print('Average Linf distance (the maximum changed values):', running_linf / len(test_dataset))
# Out:
# The dimension of an image tensor: torch.Size([3, 32, 32])
# [Prediction Result Examples]
# Original labels >>>>>>>>>>>>>>>>>>>>>>>>>
# Image #1: bird (2)
# Image #1: bird (2)
# Image #1: airplane (0)
# Image #1: cat (3)
# Predicted labels >>>>>>>>>>>>>>>>>>>>>>>>>
# Image #1: bird (2)
# Image #1: cat (3)
# Image #1: dog (5)
# Image #1: dog (5)
# Original labels >>>>>>>>>>>>>>>>>>>>>>>>>
# Image #1: deer (4)
# Image #1: bird (2)
# Image #1: airplane (0)
# Image #1: bird (2)
# Predicted labels >>>>>>>>>>>>>>>>>>>>>>>>>
# Image #1: deer (4)
# Image #1: airplane (0)
# Image #1: deer (4)
# Image #1: deer (4)
# [Step #0] Loss: 0.1159 Accuracy: 28.1250% Time elapsed: 1.5099s (total 64 images)
# [Step #10] Loss: 0.1126 Accuracy: 31.1080% Time elapsed: 10.4483s (total 704 images)
# [Step #20] Loss: 0.1152 Accuracy: 31.3988% Time elapsed: 19.4151s (total 1344 images)
# [Step #30] Loss: 0.1150 Accuracy: 31.0988% Time elapsed: 28.4703s (total 1984 images)
# [Step #40] Loss: 0.1155 Accuracy: 31.4024% Time elapsed: 37.4775s (total 2624 images)
# [Step #50] Loss: 0.1136 Accuracy: 32.1998% Time elapsed: 46.4972s (total 3264 images)
# [Step #60] Loss: 0.1148 Accuracy: 31.7367% Time elapsed: 55.5428s (total 3904 images)
# [Step #70] Loss: 0.1156 Accuracy: 31.7121% Time elapsed: 64.6357s (total 4544 images)
# [Step #80] Loss: 0.1149 Accuracy: 31.6358% Time elapsed: 73.7571s (total 5184 images)
# [Step #90] Loss: 0.1146 Accuracy: 31.7994% Time elapsed: 82.9105s (total 5824 images)
# [Step #100] Loss: 0.1147 Accuracy: 31.7915% Time elapsed: 92.0531s (total 6464 images)
# [Step #110] Loss: 0.1156 Accuracy: 31.6019% Time elapsed: 101.2099s (total 7104 images)
# [Step #120] Loss: 0.1161 Accuracy: 31.5083% Time elapsed: 110.3713s (total 7744 images)
# [Step #130] Loss: 0.1159 Accuracy: 31.7271% Time elapsed: 119.5204s (total 8384 images)
# [Step #140] Loss: 0.1159 Accuracy: 31.8373% Time elapsed: 128.6796s (total 9024 images)
# [Step #150] Loss: 0.1157 Accuracy: 31.8709% Time elapsed: 137.8291s (total 9664 images)
# [Validation] Loss: 0.1164 Accuracy: 31.8400% Time elapsed: 143.8783s (total 10000 images)
# [Size of Perturbation]
# Average L0 distance (the number of changed parameters): 3066.0778
# Average L2 distance: 0.24999971160888673
# Average MSE: 2.034500530571677e-05
# Average Linf distance (the maximum changed values): 0.0252614298671484

# %% [markdown]
# #### <b>Adversarial Attack Example 2</b>
#
# * <b>Attack method</b>: 7-step L2 PGD
# * <b>Images</b>: 5,000 valiation images
# * <b>Epsilon size</b>: 0.5

# %%
import time
from advertorch.attacks import L2PGDAttack

criterion = nn.CrossEntropyLoss()
model.eval()
start_time = time.time()

adversary = L2PGDAttack(
    model, loss_fn=nn.CrossEntropyLoss(reduction="sum"),
    eps=0.5, nb_iter=7, eps_iter=0.5/4, clip_min=0.0, clip_max=1.0, targeted=False)

running_loss = 0.
running_corrects = 0
running_length = 0

running_l0 = 0
running_l2 = 0
running_mse = 0
running_linf = 0

for i, (inputs, labels) in enumerate(test_dataloader):
    inputs = inputs.to(device)
    labels = labels.to(device)

    adv_untargeted = adversary.perturb(inputs, labels) # adversarial attack

    outputs = model(adv_untargeted)
    _, preds = torch.max(outputs, 1)
    loss = criterion(outputs, labels)

    running_loss += loss.item()
    running_corrects += torch.sum(preds == labels.data)
    running_length += labels.shape[0]

    l0, l2, mse, linf = get_distance(adv_untargeted, inputs)
    running_l0 += l0.sum().item()
    running_l2 += l2.sum().item()
    running_mse += mse.sum().item()
    running_linf += linf.sum().item()

    if i == 0:
        print('The dimension of an image tensor:', inputs.shape[1:])
        print('[Prediction Result Examples]')
        images = torchvision.utils.make_grid(adv_untargeted[:4])
        imshow_batch(images.cpu(), title='original labels:' + str([int(x) for x in labels[:4]]) +
                      '\npredicted labels:' + str([int(x) for x in preds[:4]]))
        print('Original labels >>>>>>>>>>>>>>>>>>>>>>>>>')
        for j, label in enumerate(labels[:4]):
            print(f'Image #{i + 1}: {class_names[label]} ({label})')
        print('Predicted labels >>>>>>>>>>>>>>>>>>>>>>>>>')
        for j, label in enumerate(preds[:4]):
            print(f'Image #{i + 1}: {class_names[label]} ({label})')
        images = torchvision.utils.make_grid(adv_untargeted[4:8])
        imshow_batch(images.cpu(), title='original labels:' + str([int(x) for x in labels[4:8]]) +
                      '\npredicted labels:' + str([int(x) for x in preds[4:8]]))
        print('Original labels >>>>>>>>>>>>>>>>>>>>>>>>>')
        for j, label in enumerate(labels[4:8]):
            print(f'Image #{i + 1}: {class_names[label]} ({label})')
        print('Predicted labels >>>>>>>>>>>>>>>>>>>>>>>>>')
        for j, label in enumerate(preds[4:8]):
            print(f'Image #{i + 1}: {class_names[label]} ({label})')

    if i % 10 == 0:
        cur_running_loss = running_loss / running_length
        running_acc = running_corrects / running_length * 100.
        print('[Step #{}] Loss: {:.4f} Accuracy: {:.4f}% Time elapsed: {:.4f}s (total {} images)'.format(i, cur_running_loss, running_acc, time.time() - start_time, running_length))

epoch_loss = running_loss / len(test_dataset)
epoch_acc = running_corrects / len(test_dataset) * 100.
print('[Validation] Loss: {:.4f} Accuracy: {:.4f}% Time elapsed: {:.4f}s (total {} images)'.format(epoch_loss, epoch_acc, time.time() - start_time, len(test_dataset)))

print('[Size of Perturbation]')
print('Average L0 distance (the number of changed parameters):', running_l0 / len(test_dataset))
print('Average L2 distance:', running_l2 / len(test_dataset))
print('Average MSE:', running_mse / len(test_dataset))
print('Average Linf distance (the maximum changed values):', running_linf / len(test_dataset))
# Out:
# The dimension of an image tensor: torch.Size([3, 32, 32])
# [Prediction Result Examples]
# Original labels >>>>>>>>>>>>>>>>>>>>>>>>>
# Image #1: ship (8)
# Image #1: bird (2)
# Image #1: airplane (0)
# Image #1: frog (6)
# Predicted labels >>>>>>>>>>>>>>>>>>>>>>>>>
# Image #1: horse (7)
# Image #1: bird (2)
# Image #1: truck (9)
# Image #1: cat (3)
# Original labels >>>>>>>>>>>>>>>>>>>>>>>>>
# Image #1: bird (2)
# Image #1: automobile (1)
# Image #1: ship (8)
# Image #1: cat (3)
# Predicted labels >>>>>>>>>>>>>>>>>>>>>>>>>
# Image #1: cat (3)
# Image #1: automobile (1)
# Image #1: ship (8)
# Image #1: truck (9)
# [Step #0] Loss: 0.1857 Accuracy: 17.1875% Time elapsed: 1.4925s (total 64 images)
# [Step #10] Loss: 0.1977 Accuracy: 12.9261% Time elapsed: 10.6505s (total 704 images)
# [Step #20] Loss: 0.1940 Accuracy: 13.6905% Time elapsed: 19.8203s (total 1344 images)
# [Step #30] Loss: 0.1917 Accuracy: 14.2137% Time elapsed: 28.9758s (total 1984 images)
# [Step #40] Loss: 0.1898 Accuracy: 14.7104% Time elapsed: 38.1416s (total 2624 images)
# [Step #50] Loss: 0.1903 Accuracy: 14.0012% Time elapsed: 47.2984s (total 3264 images)
# [Step #60] Loss: 0.1905 Accuracy: 13.7039% Time elapsed: 56.4794s (total 3904 images)
# [Step #70] Loss: 0.1906 Accuracy: 13.5123% Time elapsed: 65.6378s (total 4544 images)
# [Step #80] Loss: 0.1903 Accuracy: 13.5995% Time elapsed: 74.8069s (total 5184 images)
# [Step #90] Loss: 0.1902 Accuracy: 13.5130% Time elapsed: 83.9702s (total 5824 images)
# [Step #100] Loss: 0.1896 Accuracy: 13.8150% Time elapsed: 93.1214s (total 6464 images)
# [Step #110] Loss: 0.1900 Accuracy: 13.6684% Time elapsed: 102.2858s (total 7104 images)
# [Step #120] Loss: 0.1899 Accuracy: 13.5976% Time elapsed: 111.4263s (total 7744 images)
# [Step #130] Loss: 0.1897 Accuracy: 13.6689% Time elapsed: 120.5910s (total 8384 images)
# [Step #140] Loss: 0.1895 Accuracy: 13.6857% Time elapsed: 129.7490s (total 9024 images)
# [Step #150] Loss: 0.1899 Accuracy: 13.5141% Time elapsed: 138.8983s (total 9664 images)
# [Validation] Loss: 0.1905 Accuracy: 13.5600% Time elapsed: 144.9606s (total 10000 images)
# [Size of Perturbation]
# Average L0 distance (the number of changed parameters): 3067.007
# Average L2 distance: 0.49999545154571534
# Average MSE: 8.137875760439783e-05
# Average Linf distance (the maximum changed values): 0.0438222184419632

# %% [markdown]
# #### <b>Adversarial Attack Example 3</b>
#
# * <b>Attack method</b>: 7-step L2 PGD
# * <b>Images</b>: 5,000 valiation images
# * <b>Epsilon size</b>: 1.0

# %%
import time
from advertorch.attacks import L2PGDAttack

criterion = nn.CrossEntropyLoss()
model.eval()
start_time = time.time()

adversary = L2PGDAttack(
    model, loss_fn=nn.CrossEntropyLoss(reduction="sum"),
    eps=1.0, nb_iter=7, eps_iter=1.0/4, clip_min=0.0, clip_max=1.0, targeted=False)

running_loss = 0.
running_corrects = 0
running_length = 0

running_l0 = 0
running_l2 = 0
running_mse = 0
running_linf = 0

for i, (inputs, labels) in enumerate(test_dataloader):
    inputs = inputs.to(device)
    labels = labels.to(device)

    adv_untargeted = adversary.perturb(inputs, labels) # adversarial attack

    outputs = model(adv_untargeted)
    _, preds = torch.max(outputs, 1)
    loss = criterion(outputs, labels)

    running_loss += loss.item()
    running_corrects += torch.sum(preds == labels.data)
    running_length += labels.shape[0]

    l0, l2, mse, linf = get_distance(adv_untargeted, inputs)
    running_l0 += l0.sum().item()
    running_l2 += l2.sum().item()
    running_mse += mse.sum().item()
    running_linf += linf.sum().item()

    if i == 0:
        print('The dimension of an image tensor:', inputs.shape[1:])
        print('[Prediction Result Examples]')
        images = torchvision.utils.make_grid(adv_untargeted[:4])
        imshow_batch(images.cpu(), title='original labels:' + str([int(x) for x in labels[:4]]) +
                      '\npredicted labels:' + str([int(x) for x in preds[:4]]))
        print('Original labels >>>>>>>>>>>>>>>>>>>>>>>>>')
        for j, label in enumerate(labels[:4]):
            print(f'Image #{i + 1}: {class_names[label]} ({label})')
        print('Predicted labels >>>>>>>>>>>>>>>>>>>>>>>>>')
        for j, label in enumerate(preds[:4]):
            print(f'Image #{i + 1}: {class_names[label]} ({label})')
        images = torchvision.utils.make_grid(adv_untargeted[4:8])
        imshow_batch(images.cpu(), title='original labels:' + str([int(x) for x in labels[4:8]]) +
                      '\npredicted labels:' + str([int(x) for x in preds[4:8]]))
        print('Original labels >>>>>>>>>>>>>>>>>>>>>>>>>')
        for j, label in enumerate(labels[4:8]):
            print(f'Image #{i + 1}: {class_names[label]} ({label})')
        print('Predicted labels >>>>>>>>>>>>>>>>>>>>>>>>>')
        for j, label in enumerate(preds[4:8]):
            print(f'Image #{i + 1}: {class_names[label]} ({label})')

    if i % 10 == 0:
        cur_running_loss = running_loss / running_length
        running_acc = running_corrects / running_length * 100.
        print('[Step #{}] Loss: {:.4f} Accuracy: {:.4f}% Time elapsed: {:.4f}s (total {} images)'.format(i, cur_running_loss, running_acc, time.time() - start_time, running_length))

epoch_loss = running_loss / len(test_dataset)
epoch_acc = running_corrects / len(test_dataset) * 100.
print('[Validation] Loss: {:.4f} Accuracy: {:.4f}% Time elapsed: {:.4f}s (total {} images)'.format(epoch_loss, epoch_acc, time.time() - start_time, len(test_dataset)))

print('[Size of Perturbation]')
print('Average L0 distance (the number of changed parameters):', running_l0 / len(test_dataset))
print('Average L2 distance:', running_l2 / len(test_dataset))
print('Average MSE:', running_mse / len(test_dataset))
print('Average Linf distance (the maximum changed values):', running_linf / len(test_dataset))
# Out:
# The dimension of an image tensor: torch.Size([3, 32, 32])
# [Prediction Result Examples]
# Original labels >>>>>>>>>>>>>>>>>>>>>>>>>
# Image #1: airplane (0)
# Image #1: horse (7)
# Image #1: dog (5)
# Image #1: ship (8)
# Predicted labels >>>>>>>>>>>>>>>>>>>>>>>>>
# Image #1: deer (4)
# Image #1: dog (5)
# Image #1: ship (8)
# Image #1: airplane (0)
# Original labels >>>>>>>>>>>>>>>>>>>>>>>>>
# Image #1: frog (6)
# Image #1: truck (9)
# Image #1: airplane (0)
# Image #1: truck (9)
# Predicted labels >>>>>>>>>>>>>>>>>>>>>>>>>
# Image #1: bird (2)
# Image #1: cat (3)
# Image #1: ship (8)
# Image #1: frog (6)
# [Step #0] Loss: 0.2695 Accuracy: 3.1250% Time elapsed: 1.3990s (total 64 images)
# [Step #10] Loss: 0.2524 Accuracy: 1.7045% Time elapsed: 10.5735s (total 704 images)
# [Step #20] Loss: 0.2533 Accuracy: 2.6042% Time elapsed: 19.7446s (total 1344 images)
# [Step #30] Loss: 0.2547 Accuracy: 2.3690% Time elapsed: 28.9063s (total 1984 images)
# [Step #40] Loss: 0.2561 Accuracy: 2.4771% Time elapsed: 38.0671s (total 2624 images)
# [Step #50] Loss: 0.2565 Accuracy: 2.3284% Time elapsed: 47.2266s (total 3264 images)
# [Step #60] Loss: 0.2566 Accuracy: 2.2797% Time elapsed: 56.3786s (total 3904 images)
# [Step #70] Loss: 0.2563 Accuracy: 2.2667% Time elapsed: 65.5396s (total 4544 images)
# [Step #80] Loss: 0.2559 Accuracy: 2.1798% Time elapsed: 74.6966s (total 5184 images)
# [Step #90] Loss: 0.2560 Accuracy: 2.1806% Time elapsed: 83.8557s (total 5824 images)
# [Step #100] Loss: 0.2561 Accuracy: 2.1349% Time elapsed: 93.0144s (total 6464 images)
# [Step #110] Loss: 0.2559 Accuracy: 2.1678% Time elapsed: 102.1717s (total 7104 images)
# [Step #120] Loss: 0.2560 Accuracy: 2.1952% Time elapsed: 111.3188s (total 7744 images)
# [Step #130] Loss: 0.2559 Accuracy: 2.2185% Time elapsed: 120.4725s (total 8384 images)
# [Step #140] Loss: 0.2558 Accuracy: 2.1831% Time elapsed: 129.6232s (total 9024 images)
# [Step #150] Loss: 0.2554 Accuracy: 2.3386% Time elapsed: 138.7848s (total 9664 images)
# [Validation] Loss: 0.2569 Accuracy: 2.3800% Time elapsed: 144.8496s (total 10000 images)
# [Size of Perturbation]
# Average L0 distance (the number of changed parameters): 3068.1654
# Average L2 distance: 0.9999892738342285
# Average MSE: 0.0003255138802342117
# Average Linf distance (the maximum changed values): 0.07733371281623841

# %% [markdown]
# #### <b>Adversarial Attack Example 4</b>
#
# * <b>Attack method</b>: 7-step L2 PGD
# * <b>Images</b>: 5,000 valiation images
# * <b>Epsilon size</b>: 2.0

# %%
import time
from advertorch.attacks import L2PGDAttack

criterion = nn.CrossEntropyLoss()
model.eval()
start_time = time.time()

adversary = L2PGDAttack(
    model, loss_fn=nn.CrossEntropyLoss(reduction="sum"),
    eps=2.0, nb_iter=7, eps_iter=2.0/4, clip_min=0.0, clip_max=1.0, targeted=False)

running_loss = 0.
running_corrects = 0
running_length = 0

running_l0 = 0
running_l2 = 0
running_mse = 0
running_linf = 0

for i, (inputs, labels) in enumerate(test_dataloader):
    inputs = inputs.to(device)
    labels = labels.to(device)

    adv_untargeted = adversary.perturb(inputs, labels) # adversarial attack

    outputs = model(adv_untargeted)
    _, preds = torch.max(outputs, 1)
    loss = criterion(outputs, labels)

    running_loss += loss.item()
    running_corrects += torch.sum(preds == labels.data)
    running_length += labels.shape[0]

    l0, l2, mse, linf = get_distance(adv_untargeted, inputs)
    running_l0 += l0.sum().item()
    running_l2 += l2.sum().item()
    running_mse += mse.sum().item()
    running_linf += linf.sum().item()

    if i == 0:
        print('The dimension of an image tensor:', inputs.shape[1:])
        print('[Prediction Result Examples]')
        images = torchvision.utils.make_grid(adv_untargeted[:4])
        imshow_batch(images.cpu(), title='original labels:' + str([int(x) for x in labels[:4]]) +
                      '\npredicted labels:' + str([int(x) for x in preds[:4]]))
        print('Original labels >>>>>>>>>>>>>>>>>>>>>>>>>')
        for j, label in enumerate(labels[:4]):
            print(f'Image #{i + 1}: {class_names[label]} ({label})')
        print('Predicted labels >>>>>>>>>>>>>>>>>>>>>>>>>')
        for j, label in enumerate(preds[:4]):
            print(f'Image #{i + 1}: {class_names[label]} ({label})')
        images = torchvision.utils.make_grid(adv_untargeted[4:8])
        imshow_batch(images.cpu(), title='original labels:' + str([int(x) for x in labels[4:8]]) +
                      '\npredicted labels:' + str([int(x) for x in preds[4:8]]))
        print('Original labels >>>>>>>>>>>>>>>>>>>>>>>>>')
        for j, label in enumerate(labels[4:8]):
            print(f'Image #{i + 1}: {class_names[label]} ({label})')
        print('Predicted labels >>>>>>>>>>>>>>>>>>>>>>>>>')
        for j, label in enumerate(preds[4:8]):
            print(f'Image #{i + 1}: {class_names[label]} ({label})')

    if i % 10 == 0:
        cur_running_loss = running_loss / running_length
        running_acc = running_corrects / running_length * 100.
        print('[Step #{}] Loss: {:.4f} Accuracy: {:.4f}% Time elapsed: {:.4f}s (total {} images)'.format(i, cur_running_loss, running_acc, time.time() - start_time, running_length))

epoch_loss = running_loss / len(test_dataset)
epoch_acc = running_corrects / len(test_dataset) * 100.
print('[Validation] Loss: {:.4f} Accuracy: {:.4f}% Time elapsed: {:.4f}s (total {} images)'.format(epoch_loss, epoch_acc, time.time() - start_time, len(test_dataset)))

print('[Size of Perturbation]')
print('Average L0 distance (the number of changed parameters):', running_l0 / len(test_dataset))
print('Average L2 distance:', running_l2 / len(test_dataset))
print('Average MSE:', running_mse / len(test_dataset))
print('Average Linf distance (the maximum changed values):', running_linf / len(test_dataset))
# Out:
# The dimension of an image tensor: torch.Size([3, 32, 32])
# [Prediction Result Examples]
# Original labels >>>>>>>>>>>>>>>>>>>>>>>>>
# Image #1: bird (2)
# Image #1: frog (6)
# Image #1: airplane (0)
# Image #1: automobile (1)
# Predicted labels >>>>>>>>>>>>>>>>>>>>>>>>>
# Image #1: cat (3)
# Image #1: deer (4)
# Image #1: cat (3)
# Image #1: deer (4)
# Original labels >>>>>>>>>>>>>>>>>>>>>>>>>
# Image #1: truck (9)
# Image #1: airplane (0)
# Image #1: horse (7)
# Image #1: dog (5)
# Predicted labels >>>>>>>>>>>>>>>>>>>>>>>>>
# Image #1: frog (6)
# Image #1: cat (3)
# Image #1: cat (3)
# Image #1: bird (2)
# [Step #0] Loss: 0.3037 Accuracy: 0.0000% Time elapsed: 1.3878s (total 64 images)
# [Step #10] Loss: 0.2904 Accuracy: 0.4261% Time elapsed: 10.5662s (total 704 images)
# [Step #20] Loss: 0.2929 Accuracy: 0.2976% Time elapsed: 19.7257s (total 1344 images)
# [Step #30] Loss: 0.2935 Accuracy: 0.2016% Time elapsed: 28.8916s (total 1984 images)
# [Step #40] Loss: 0.2934 Accuracy: 0.1905% Time elapsed: 38.0490s (total 2624 images)
# [Step #50] Loss: 0.2943 Accuracy: 0.1532% Time elapsed: 47.2091s (total 3264 images)
# [Step #60] Loss: 0.2943 Accuracy: 0.1281% Time elapsed: 56.3810s (total 3904 images)
# [Step #70] Loss: 0.2939 Accuracy: 0.1540% Time elapsed: 65.5627s (total 4544 images)
# [Step #80] Loss: 0.2944 Accuracy: 0.1543% Time elapsed: 74.7165s (total 5184 images)
# [Step #90] Loss: 0.2947 Accuracy: 0.1374% Time elapsed: 83.8768s (total 5824 images)
# [Step #100] Loss: 0.2950 Accuracy: 0.1392% Time elapsed: 93.0377s (total 6464 images)
# [Step #110] Loss: 0.2952 Accuracy: 0.1267% Time elapsed: 102.2058s (total 7104 images)
# [Step #120] Loss: 0.2953 Accuracy: 0.1420% Time elapsed: 111.3687s (total 7744 images)
# [Step #130] Loss: 0.2952 Accuracy: 0.1431% Time elapsed: 120.5252s (total 8384 images)
# [Step #140] Loss: 0.2953 Accuracy: 0.1330% Time elapsed: 129.6821s (total 9024 images)
# [Step #150] Loss: 0.2952 Accuracy: 0.1345% Time elapsed: 138.8178s (total 9664 images)
# [Validation] Loss: 0.2965 Accuracy: 0.1300% Time elapsed: 144.8775s (total 10000 images)
# [Size of Perturbation]
# Average L0 distance (the number of changed parameters): 3069.0151
# Average L2 distance: 1.9999955200195312
# Average MSE: 0.0013020774889737367
# Average Linf distance (the maximum changed values): 0.14137559168338776

# %% [markdown]
# #### <b>Adversarial Attack Example 5</b>
#
# * <b>Attack method</b>: 7-step L2 PGD
# * <b>Images</b>: 5,000 valiation images
# * <b>Epsilon size</b>: 4.0

# %%
import time
from advertorch.attacks import L2PGDAttack

criterion = nn.CrossEntropyLoss()
model.eval()
start_time = time.time()

adversary = L2PGDAttack(
    model, loss_fn=nn.CrossEntropyLoss(reduction="sum"),
    eps=4.0, nb_iter=7, eps_iter=4.0/4, clip_min=0.0, clip_max=1.0, targeted=False)

running_loss = 0.
running_corrects = 0
running_length = 0

running_l0 = 0
running_l2 = 0
running_mse = 0
running_linf = 0

for i, (inputs, labels) in enumerate(test_dataloader):
    inputs = inputs.to(device)
    labels = labels.to(device)

    adv_untargeted = adversary.perturb(inputs, labels) # adversarial attack

    outputs = model(adv_untargeted)
    _, preds = torch.max(outputs, 1)
    loss = criterion(outputs, labels)

    running_loss += loss.item()
    running_corrects += torch.sum(preds == labels.data)
    running_length += labels.shape[0]

    l0, l2, mse, linf = get_distance(adv_untargeted, inputs)
    running_l0 += l0.sum().item()
    running_l2 += l2.sum().item()
    running_mse += mse.sum().item()
    running_linf += linf.sum().item()

    if i == 0:
        print('The dimension of an image tensor:', inputs.shape[1:])
        print('[Prediction Result Examples]')
        images = torchvision.utils.make_grid(adv_untargeted[:4])
        imshow_batch(images.cpu(), title='original labels:' + str([int(x) for x in labels[:4]]) +
                      '\npredicted labels:' + str([int(x) for x in preds[:4]]))
        print('Original labels >>>>>>>>>>>>>>>>>>>>>>>>>')
        for j, label in enumerate(labels[:4]):
            print(f'Image #{i + 1}: {class_names[label]} ({label})')
        print('Predicted labels >>>>>>>>>>>>>>>>>>>>>>>>>')
        for j, label in enumerate(preds[:4]):
            print(f'Image #{i + 1}: {class_names[label]} ({label})')
        images = torchvision.utils.make_grid(adv_untargeted[4:8])
        imshow_batch(images.cpu(), title='original labels:' + str([int(x) for x in labels[4:8]]) +
                      '\npredicted labels:' + str([int(x) for x in preds[4:8]]))
        print('Original labels >>>>>>>>>>>>>>>>>>>>>>>>>')
        for j, label in enumerate(labels[4:8]):
            print(f'Image #{i + 1}: {class_names[label]} ({label})')
        print('Predicted labels >>>>>>>>>>>>>>>>>>>>>>>>>')
        for j, label in enumerate(preds[4:8]):
            print(f'Image #{i + 1}: {class_names[label]} ({label})')

    if i % 10 == 0:
        cur_running_loss = running_loss / running_length
        running_acc = running_corrects / running_length * 100.
        print('[Step #{}] Loss: {:.4f} Accuracy: {:.4f}% Time elapsed: {:.4f}s (total {} images)'.format(i, cur_running_loss, running_acc, time.time() - start_time, running_length))

epoch_loss = running_loss / len(test_dataset)
epoch_acc = running_corrects / len(test_dataset) * 100.
print('[Validation] Loss: {:.4f} Accuracy: {:.4f}% Time elapsed: {:.4f}s (total {} images)'.format(epoch_loss, epoch_acc, time.time() - start_time, len(test_dataset)))

print('[Size of Perturbation]')
print('Average L0 distance (the number of changed parameters):', running_l0 / len(test_dataset))
print('Average L2 distance:', running_l2 / len(test_dataset))
print('Average MSE:', running_mse / len(test_dataset))
print('Average Linf distance (the maximum changed values):', running_linf / len(test_dataset))
# Out:
# The dimension of an image tensor: torch.Size([3, 32, 32])
# [Prediction Result Examples]
# Original labels >>>>>>>>>>>>>>>>>>>>>>>>>
# Image #1: cat (3)
# Image #1: truck (9)
# Image #1: dog (5)
# Image #1: bird (2)
# Predicted labels >>>>>>>>>>>>>>>>>>>>>>>>>
# Image #1: frog (6)
# Image #1: frog (6)
# Image #1: bird (2)
# Image #1: frog (6)
# Original labels >>>>>>>>>>>>>>>>>>>>>>>>>
# Image #1: bird (2)
# Image #1: truck (9)
# Image #1: ship (8)
# Image #1: frog (6)
# Predicted labels >>>>>>>>>>>>>>>>>>>>>>>>>
# Image #1: frog (6)
# Image #1: frog (6)
# Image #1: airplane (0)
# Image #1: bird (2)
# [Step #0] Loss: 0.3209 Accuracy: 0.0000% Time elapsed: 1.3817s (total 64 images)
# [Step #10] Loss: 0.3153 Accuracy: 0.0000% Time elapsed: 10.5423s (total 704 images)
# [Step #20] Loss: 0.3151 Accuracy: 0.0000% Time elapsed: 19.6805s (total 1344 images)
# [Step #30] Loss: 0.3151 Accuracy: 0.0000% Time elapsed: 28.8367s (total 1984 images)
# [Step #40] Loss: 0.3161 Accuracy: 0.0000% Time elapsed: 37.9886s (total 2624 images)
# [Step #50] Loss: 0.3160 Accuracy: 0.0000% Time elapsed: 47.1268s (total 3264 images)
# [Step #60] Loss: 0.3166 Accuracy: 0.0000% Time elapsed: 56.2744s (total 3904 images)
# [Step #70] Loss: 0.3169 Accuracy: 0.0000% Time elapsed: 65.4168s (total 4544 images)
# [Step #80] Loss: 0.3167 Accuracy: 0.0000% Time elapsed: 74.5498s (total 5184 images)
# [Step #90] Loss: 0.3163 Accuracy: 0.0000% Time elapsed: 83.6900s (total 5824 images)
# [Step #100] Loss: 0.3164 Accuracy: 0.0000% Time elapsed: 92.8307s (total 6464 images)
# [Step #110] Loss: 0.3165 Accuracy: 0.0000% Time elapsed: 101.9872s (total 7104 images)
# [Step #120] Loss: 0.3163 Accuracy: 0.0000% Time elapsed: 111.1503s (total 7744 images)
# [Step #130] Loss: 0.3159 Accuracy: 0.0000% Time elapsed: 120.2991s (total 8384 images)
# [Step #140] Loss: 0.3159 Accuracy: 0.0000% Time elapsed: 129.4611s (total 9024 images)
# [Step #150] Loss: 0.3159 Accuracy: 0.0000% Time elapsed: 138.6376s (total 9664 images)
# [Validation] Loss: 0.3174 Accuracy: 0.0000% Time elapsed: 144.7037s (total 10000 images)
# [Size of Perturbation]
# Average L0 distance (the number of changed parameters): 3069.4227
# Average L2 distance: 3.999999099731445
# Average MSE: 0.005208330893516541
# Average Linf distance (the maximum changed values): 0.2679576214313507

# %% [markdown]
# #### <b>Adversarial Attack Example 6</b>
#
# * <b>Attack method</b>: 7-step L2 PGD
# * <b>Images</b>: 5,000 valiation images
# * <b>Epsilon size</b>: 8.0

# %%
import time
from advertorch.attacks import L2PGDAttack

criterion = nn.CrossEntropyLoss()
model.eval()
start_time = time.time()

adversary = L2PGDAttack(
    model, loss_fn=nn.CrossEntropyLoss(reduction="sum"),
    eps=8.0, nb_iter=7, eps_iter=8.0/4, clip_min=0.0, clip_max=1.0, targeted=False)

running_loss = 0.
running_corrects = 0
running_length = 0

running_l0 = 0
running_l2 = 0
running_mse = 0
running_linf = 0

for i, (inputs, labels) in enumerate(test_dataloader):
    inputs = inputs.to(device)
    labels = labels.to(device)

    adv_untargeted = adversary.perturb(inputs, labels) # adversarial attack

    outputs = model(adv_untargeted)
    _, preds = torch.max(outputs, 1)
    loss = criterion(outputs, labels)

    running_loss += loss.item()
    running_corrects += torch.sum(preds == labels.data)
    running_length += labels.shape[0]

    l0, l2, mse, linf = get_distance(adv_untargeted, inputs)
    running_l0 += l0.sum().item()
    running_l2 += l2.sum().item()
    running_mse += mse.sum().item()
    running_linf += linf.sum().item()

    if i == 0:
        print('The dimension of an image tensor:', inputs.shape[1:])
        print('[Prediction Result Examples]')
        images = torchvision.utils.make_grid(adv_untargeted[:4])
        imshow_batch(images.cpu(), title='original labels:' + str([int(x) for x in labels[:4]]) +
                      '\npredicted labels:' + str([int(x) for x in preds[:4]]))
        print('Original labels >>>>>>>>>>>>>>>>>>>>>>>>>')
        for j, label in enumerate(labels[:4]):
            print(f'Image #{i + 1}: {class_names[label]} ({label})')
        print('Predicted labels >>>>>>>>>>>>>>>>>>>>>>>>>')
        for j, label in enumerate(preds[:4]):
            print(f'Image #{i + 1}: {class_names[label]} ({label})')
        images = torchvision.utils.make_grid(adv_untargeted[4:8])
        imshow_batch(images.cpu(), title='original labels:' + str([int(x) for x in labels[4:8]]) +
                      '\npredicted labels:' + str([int(x) for x in preds[4:8]]))
        print('Original labels >>>>>>>>>>>>>>>>>>>>>>>>>')
        for j, label in enumerate(labels[4:8]):
            print(f'Image #{i + 1}: {class_names[label]} ({label})')
        print('Predicted labels >>>>>>>>>>>>>>>>>>>>>>>>>')
        for j, label in enumerate(preds[4:8]):
            print(f'Image #{i + 1}: {class_names[label]} ({label})')

    if i % 10 == 0:
        cur_running_loss = running_loss / running_length
        running_acc = running_corrects / running_length * 100.
        print('[Step #{}] Loss: {:.4f} Accuracy: {:.4f}% Time elapsed: {:.4f}s (total {} images)'.format(i, cur_running_loss, running_acc, time.time() - start_time, running_length))

epoch_loss = running_loss / len(test_dataset)
epoch_acc = running_corrects / len(test_dataset) * 100.
print('[Validation] Loss: {:.4f} Accuracy: {:.4f}% Time elapsed: {:.4f}s (total {} images)'.format(epoch_loss, epoch_acc, time.time() - start_time, len(test_dataset)))

print('[Size of Perturbation]')
print('Average L0 distance (the number of changed parameters):', running_l0 / len(test_dataset))
print('Average L2 distance:', running_l2 / len(test_dataset))
print('Average MSE:', running_mse / len(test_dataset))
print('Average Linf distance (the maximum changed values):', running_linf / len(test_dataset))
# Out:
# The dimension of an image tensor: torch.Size([3, 32, 32])
# [Prediction Result Examples]
# Original labels >>>>>>>>>>>>>>>>>>>>>>>>>
# Image #1: cat (3)
# Image #1: truck (9)
# Image #1: truck (9)
# Image #1: cat (3)
# Predicted labels >>>>>>>>>>>>>>>>>>>>>>>>>
# Image #1: bird (2)
# Image #1: bird (2)
# Image #1: bird (2)
# Image #1: bird (2)
# Original labels >>>>>>>>>>>>>>>>>>>>>>>>>
# Image #1: automobile (1)
# Image #1: bird (2)
# Image #1: bird (2)
# Image #1: deer (4)
# Predicted labels >>>>>>>>>>>>>>>>>>>>>>>>>
# Image #1: bird (2)
# Image #1: frog (6)
# Image #1: frog (6)
# Image #1: bird (2)
# [Step #0] Loss: 0.3411 Accuracy: 0.0000% Time elapsed: 1.3995s (total 64 images)
# [Step #10] Loss: 0.3505 Accuracy: 0.0000% Time elapsed: 10.5462s (total 704 images)
# [Step #20] Loss: 0.3514 Accuracy: 0.0000% Time elapsed: 19.6924s (total 1344 images)
# [Step #30] Loss: 0.3518 Accuracy: 0.0000% Time elapsed: 28.8266s (total 1984 images)
# [Step #40] Loss: 0.3523 Accuracy: 0.0000% Time elapsed: 37.9887s (total 2624 images)
# [Step #50] Loss: 0.3516 Accuracy: 0.0000% Time elapsed: 47.1559s (total 3264 images)
# [Step #60] Loss: 0.3518 Accuracy: 0.0000% Time elapsed: 56.3199s (total 3904 images)
# [Step #70] Loss: 0.3516 Accuracy: 0.0000% Time elapsed: 65.4758s (total 4544 images)
# [Step #80] Loss: 0.3519 Accuracy: 0.0000% Time elapsed: 74.6359s (total 5184 images)
# [Step #90] Loss: 0.3518 Accuracy: 0.0000% Time elapsed: 83.7973s (total 5824 images)
# [Step #100] Loss: 0.3513 Accuracy: 0.0000% Time elapsed: 92.9638s (total 6464 images)
# [Step #110] Loss: 0.3514 Accuracy: 0.0000% Time elapsed: 102.1286s (total 7104 images)
# [Step #120] Loss: 0.3514 Accuracy: 0.0000% Time elapsed: 111.2842s (total 7744 images)
# [Step #130] Loss: 0.3512 Accuracy: 0.0000% Time elapsed: 120.4455s (total 8384 images)
# [Step #140] Loss: 0.3511 Accuracy: 0.0000% Time elapsed: 129.6061s (total 9024 images)
# [Step #150] Loss: 0.3513 Accuracy: 0.0000% Time elapsed: 138.7665s (total 9664 images)
# [Validation] Loss: 0.3528 Accuracy: 0.0000% Time elapsed: 144.8279s (total 10000 images)
# [Size of Perturbation]
# Average L0 distance (the number of changed parameters): 3069.4453
# Average L2 distance: 8.0
# Average MSE: 0.020833333444595335
# Average Linf distance (the maximum changed values): 0.5231270611763

# %% [markdown]
# #### <b>Comparison with Foolbox</b>
#
# * <b>Attack method</b>: 7-step L2 PGD
# * <b>Images</b>: 5,000 valiation images
# * <b>Epsilon size</b>: 0.25

# %%
import time
import foolbox as fb

criterion = nn.CrossEntropyLoss()
model.eval()
start_time = time.time()

fmodel = fb.PyTorchModel(model, bounds=(0, 1))
attack = fb.attacks.L2ProjectedGradientDescentAttack(abs_stepsize=0.25/4, steps=7)

running_loss = 0.
running_corrects = 0
running_length = 0

running_l0 = 0
running_l2 = 0
running_mse = 0
running_linf = 0

for i, (inputs, labels) in enumerate(test_dataloader):
    inputs = inputs.to(device)
    labels = labels.to(device)

    _, adv_untargeted, _ = attack(fmodel, inputs, labels, epsilons=0.25) # adversarial attack

    outputs = model(adv_untargeted)
    _, preds = torch.max(outputs, 1)
    loss = criterion(outputs, labels)

    running_loss += loss.item()
    running_corrects += torch.sum(preds == labels.data)
    running_length += labels.shape[0]

    l0, l2, mse, linf = get_distance(adv_untargeted, inputs)
    running_l0 += l0.sum().item()
    running_l2 += l2.sum().item()
    running_mse += mse.sum().item()
    running_linf += linf.sum().item()

    if i == 0:
        print('The dimension of an image tensor:', inputs.shape[1:])
        print('[Prediction Result Examples]')
        images = torchvision.utils.make_grid(adv_untargeted[:4])
        imshow_batch(images.cpu(), title='original labels:' + str([int(x) for x in labels[:4]]) +
                      '\npredicted labels:' + str([int(x) for x in preds[:4]]))
        print('Original labels >>>>>>>>>>>>>>>>>>>>>>>>>')
        for j, label in enumerate(labels[:4]):
            print(f'Image #{i + 1}: {class_names[label]} ({label})')
        print('Predicted labels >>>>>>>>>>>>>>>>>>>>>>>>>')
        for j, label in enumerate(preds[:4]):
            print(f'Image #{i + 1}: {class_names[label]} ({label})')
        images = torchvision.utils.make_grid(adv_untargeted[4:8])
        imshow_batch(images.cpu(), title='original labels:' + str([int(x) for x in labels[4:8]]) +
                      '\npredicted labels:' + str([int(x) for x in preds[4:8]]))
        print('Original labels >>>>>>>>>>>>>>>>>>>>>>>>>')
        for j, label in enumerate(labels[4:8]):
            print(f'Image #{i + 1}: {class_names[label]} ({label})')
        print('Predicted labels >>>>>>>>>>>>>>>>>>>>>>>>>')
        for j, label in enumerate(preds[4:8]):
            print(f'Image #{i + 1}: {class_names[label]} ({label})')

    if i % 10 == 0:
        cur_running_loss = running_loss / running_length
        running_acc = running_corrects / running_length * 100.
        print('[Step #{}] Loss: {:.4f} Accuracy: {:.4f}% Time elapsed: {:.4f}s (total {} images)'.format(i, cur_running_loss, running_acc, time.time() - start_time, running_length))

epoch_loss = running_loss / len(test_dataset)
epoch_acc = running_corrects / len(test_dataset) * 100.
print('[Validation] Loss: {:.4f} Accuracy: {:.4f}% Time elapsed: {:.4f}s (total {} images)'.format(epoch_loss, epoch_acc, time.time() - start_time, len(test_dataset)))

print('[Size of Perturbation]')
print('Average L0 distance (the number of changed parameters):', running_l0 / len(test_dataset))
print('Average L2 distance:', running_l2 / len(test_dataset))
print('Average MSE:', running_mse / len(test_dataset))
print('Average Linf distance (the maximum changed values):', running_linf / len(test_dataset))
# Out:
# The dimension of an image tensor: torch.Size([3, 32, 32])
# [Prediction Result Examples]
# Original labels >>>>>>>>>>>>>>>>>>>>>>>>>
# Image #1: automobile (1)
# Image #1: airplane (0)
# Image #1: dog (5)
# Image #1: frog (6)
# Predicted labels >>>>>>>>>>>>>>>>>>>>>>>>>
# Image #1: automobile (1)
# Image #1: bird (2)
# Image #1: airplane (0)
# Image #1: deer (4)
# Original labels >>>>>>>>>>>>>>>>>>>>>>>>>
# Image #1: horse (7)
# Image #1: horse (7)
# Image #1: automobile (1)
# Image #1: automobile (1)
# Predicted labels >>>>>>>>>>>>>>>>>>>>>>>>>
# Image #1: bird (2)
# Image #1: deer (4)
# Image #1: cat (3)
# Image #1: automobile (1)
# [Step #0] Loss: 0.1061 Accuracy: 34.3750% Time elapsed: 1.5646s (total 64 images)
# [Step #10] Loss: 0.1224 Accuracy: 28.2670% Time elapsed: 10.9528s (total 704 images)
# [Step #20] Loss: 0.1175 Accuracy: 29.7619% Time elapsed: 20.3596s (total 1344 images)
# [Step #30] Loss: 0.1171 Accuracy: 30.6452% Time elapsed: 29.8077s (total 1984 images)
# [Step #40] Loss: 0.1180 Accuracy: 30.3735% Time elapsed: 39.2871s (total 2624 images)
# [Step #50] Loss: 0.1176 Accuracy: 31.0662% Time elapsed: 48.7999s (total 3264 images)
# [Step #60] Loss: 0.1177 Accuracy: 30.9426% Time elapsed: 58.3113s (total 3904 images)
# [Step #70] Loss: 0.1179 Accuracy: 31.2060% Time elapsed: 67.8265s (total 4544 images)
# [Step #80] Loss: 0.1181 Accuracy: 31.1150% Time elapsed: 77.3292s (total 5184 images)
# [Step #90] Loss: 0.1176 Accuracy: 31.5247% Time elapsed: 86.8345s (total 5824 images)
# [Step #100] Loss: 0.1169 Accuracy: 31.7141% Time elapsed: 96.3531s (total 6464 images)
# [Step #110] Loss: 0.1166 Accuracy: 31.6723% Time elapsed: 105.8702s (total 7104 images)
# [Step #120] Loss: 0.1164 Accuracy: 31.5987% Time elapsed: 115.3780s (total 7744 images)
# [Step #130] Loss: 0.1160 Accuracy: 31.5840% Time elapsed: 124.8951s (total 8384 images)
# [Step #140] Loss: 0.1162 Accuracy: 31.4605% Time elapsed: 134.4010s (total 9024 images)
# [Step #150] Loss: 0.1164 Accuracy: 31.3742% Time elapsed: 143.9014s (total 9664 images)
# [Validation] Loss: 0.1169 Accuracy: 31.5500% Time elapsed: 150.2787s (total 10000 images)
# [Size of Perturbation]
# Average L0 distance (the number of changed parameters): 3060.9437
# Average L2 distance: 0.249921115732193
# Average MSE: 2.03322431538254e-05
# Average Linf distance (the maximum changed values): 0.02530739233791828
